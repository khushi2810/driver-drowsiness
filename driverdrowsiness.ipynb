# %% [markdown]
# <a href="https://colab.research.google.com/github/khushi2810/driver-drowsiness/blob/main/driverdrowsiness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
labels = os.listdir("../input/drowsiness-dataset/train")

# %%
labels
# Out:
# ['Closed', 'Open', 'yawn', 'no_yawn']

# %%
import matplotlib.pyplot as plt
plt.imshow(plt.imread("../input/drowsiness-dataset/train/Closed/_0.jpg"))

# %%
a = plt.imread("../input/drowsiness-dataset/train/yawn/10.jpg")

# %%
a.shape
# Out:
# (480, 640, 3)

# %%
plt.imshow(plt.imread("../input/drowsiness-dataset/train/yawn/10.jpg"))

# %%
def face_for_yawn(direc="../input/drowsiness-dataset/train", face_cas_path="../input/predictionimages/haarcascade_frontalface_default.xml"):
    yaw_no = []
    IMG_SIZE = 145
    categories = ["yawn", "no_yawn"]
    for category in categories:
        path_link = os.path.join(direc, category)
        class_num1 = categories.index(category)
        print(class_num1)
        for image in os.listdir(path_link):
            image_array = cv2.imread(os.path.join(path_link, image), cv2.IMREAD_COLOR)
            face_cascade = cv2.CascadeClassifier(face_cas_path)
            faces = face_cascade.detectMultiScale(image_array, 1.3, 5)
            for (x, y, w, h) in faces:
                img = cv2.rectangle(image_array, (x, y), (x+w, y+h), (0, 255, 0), 2)
                roi_color = img[y:y+h, x:x+w]
                resized_array = cv2.resize(roi_color, (IMG_SIZE, IMG_SIZE))
                yaw_no.append([resized_array, class_num1])
    return yaw_no

# %%
yawn_no_yawn = face_for_yawn()
# Out:
# 0
# 1

# %%
def get_data(dir_path="../input/drowsiness-dataset/train/", face_cas="../input/predictionimages/haarcascade_frontalface_default.xml", eye_cas="../input/prediction-images/haarcascade.xml"):
    labels = ['Closed', 'Open']
    IMG_SIZE = 145
    data = []
    for label in labels:
        path = os.path.join(dir_path, label)
        class_num = labels.index(label)
        class_num +=2
        print(class_num)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                data.append([resized_array, class_num])
            except Exception as e:
                print(e)
    return data

# %%
data_train = get_data()
# Out:
# 2
# 3

# %%
def append_data():
#     total_data = []
    yaw_no = face_for_yawn()
    data = get_data()
    yaw_no.extend(data)
    return np.array(yaw_no)

# %%
new_data = append_data()
# Out:
# 0
# 1
# 2
# 3
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
X = []
y = []
for feature, label in new_data:
    X.append(feature)
    y.append(label)

# %%
X = np.array(X)
X = X.reshape(-1, 145, 145, 3)

# %%
from sklearn.preprocessing import LabelBinarizer
label_bin = LabelBinarizer()
y = label_bin.fit_transform(y)

# %%
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
seed = 42
test_size = 0.30
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=seed, test_size=test_size)

# %%
len(X_test)
# Out:
# 578

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import keras
keras.__version__
# Out:
# '2.4.3'

# %%
train_generator = ImageDataGenerator(rescale=1/255, zoom_range=0.2, horizontal_flip=True, rotation_range=30)
test_generator = ImageDataGenerator(rescale=1/255)

train_generator = train_generator.flow(np.array(X_train), y_train, shuffle=False)
test_generator = test_generator.flow(np.array(X_test), y_test, shuffle=False)

# %%
model = Sequential()

model.add(Conv2D(256, (3, 3), activation="relu", input_shape=X_train.shape[1:]))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(32, (3, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))

model.add(Flatten())
model.add(Dropout(0.5))

model.add(Dense(64, activation="relu"))
model.add(Dense(4, activation="softmax"))

model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer="adam")

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 143, 143, 256)     7168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 71, 71, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 69, 69, 128)       295040
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 34, 34, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        73792
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        18464
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1568)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1568)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                100416
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 495,140
# Trainable params: 495,140
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_generator, epochs=50, validation_data=test_generator, shuffle=True, validation_steps=len(test_generator))
# Out:
# Epoch 1/50
# 43/43 [==============================] - 14s 168ms/step - loss: 1.3372 - accuracy: 0.3703 - val_loss: 1.2425 - val_accuracy: 0.3910
# Epoch 2/50
# 43/43 [==============================] - 7s 152ms/step - loss: 0.9355 - accuracy: 0.5891 - val_loss: 0.3982 - val_accuracy: 0.8426
# Epoch 3/50
# 43/43 [==============================] - 7s 152ms/step - loss: 0.4699 - accuracy: 0.8107 - val_loss: 0.3633 - val_accuracy: 0.8668
# Epoch 4/50
# 43/43 [==============================] - 7s 161ms/step - loss: 0.4205 - accuracy: 0.8234 - val_loss: 0.3023 - val_accuracy: 0.8858
# Epoch 5/50
# 43/43 [==============================] - 6s 147ms/step - loss: 0.3698 - accuracy: 0.8503 - val_loss: 0.2955 - val_accuracy: 0.8824
# Epoch 6/50
# 43/43 [==============================] - 7s 153ms/step - loss: 0.3112 - accuracy: 0.8646 - val_loss: 0.2458 - val_accuracy: 0.8979
# Epoch 7/50
# 43/43 [==============================] - 7s 156ms/step - loss: 0.3018 - accuracy: 0.8784 - val_loss: 0.2818 - val_accuracy: 0.8824
# Epoch 8/50
# 43/43 [==============================] - 7s 161ms/step - loss: 0.3148 - accuracy: 0.8665 - val_loss: 0.2316 - val_accuracy: 0.9256
# Epoch 9/50
# 43/43 [==============================] - 7s 154ms/step - loss: 0.2415 - accuracy: 0.9069 - val_loss: 0.1929 - val_accuracy: 0.9221
# Epoch 10/50
# 43/43 [==============================] - 6s 148ms/step - loss: 0.2306 - accuracy: 0.9039 - val_loss: 0.2101 - val_accuracy: 0.9187
# Epoch 11/50
# 43/43 [==============================] - 7s 155ms/step - loss: 0.2619 - accuracy: 0.8875 - val_loss: 0.2584 - val_accuracy: 0.8997
# Epoch 12/50
# 43/43 [==============================] - 7s 157ms/step - loss: 0.2496 - accuracy: 0.9097 - val_loss: 0.1757 - val_accuracy: 0.9325
# Epoch 13/50
# 43/43 [==============================] - 7s 163ms/step - loss: 0.2210 - accuracy: 0.8968 - val_loss: 0.2070 - val_accuracy: 0.9118
# Epoch 14/50
# 43/43 [==============================] - 7s 156ms/step - loss: 0.2132 - accuracy: 0.9060 - val_loss: 0.1530 - val_accuracy: 0.9377
# Epoch 15/50
# 43/43 [==============================] - 6s 150ms/step - loss: 0.2030 - accuracy: 0.9104 - val_loss: 0.1436 - val_accuracy: 0.9446
# Epoch 16/50
# 43/43 [==============================] - 7s 153ms/step - loss: 0.2172 - accuracy: 0.9117 - val_loss: 0.1756 - val_accuracy: 0.9377
# Epoch 17/50
# 43/43 [==============================] - 7s 158ms/step - loss: 0.1739 - accuracy: 0.9294 - val_loss: 0.1648 - val_accuracy: 0.9429
# Epoch 18/50
# 43/43 [==============================] - 7s 166ms/step - loss: 0.1659 - accuracy: 0.9321 - val_loss: 0.1659 - val_accuracy: 0.9481
# Epoch 19/50
# 43/43 [==============================] - 7s 155ms/step - loss: 0.1529 - accuracy: 0.9271 - val_loss: 0.1316 - val_accuracy: 0.9481
# Epoch 20/50
# 43/43 [==============================] - 7s 152ms/step - loss: 0.1626 - accuracy: 0.9338 - val_loss: 0.1649 - val_accuracy: 0.9446
# Epoch 21/50
# 43/43 [==============================] - 6s 147ms/step - loss: 0.1666 - accuracy: 0.9353 - val_loss: 0.1280 - val_accuracy: 0.9533
# Epoch 22/50
# 43/43 [==============================] - 7s 154ms/step - loss: 0.1747 - accuracy: 0.9293 - val_loss: 0.1392 - val_accuracy: 0.9498
# Epoch 23/50
# 43/43 [==============================] - 7s 163ms/step - loss: 0.1710 - accuracy: 0.9178 - val_loss: 0.1664 - val_accuracy: 0.9377
# Epoch 24/50
# 43/43 [==============================] - 7s 156ms/step - loss: 0.1702 - accuracy: 0.9306 - val_loss: 0.1354 - val_accuracy: 0.9394
# Epoch 25/50
# 43/43 [==============================] - 7s 154ms/step - loss: 0.1732 - accuracy: 0.9384 - val_loss: 0.1116 - val_accuracy: 0.9602
# Epoch 26/50
# 43/43 [==============================] - 7s 151ms/step - loss: 0.1637 - accuracy: 0.9389 - val_loss: 0.1169 - val_accuracy: 0.9533
# Epoch 27/50
# 43/43 [==============================] - 7s 155ms/step - loss: 0.1540 - accuracy: 0.9380 - val_loss: 0.1205 - val_accuracy: 0.9498
# Epoch 28/50
# 43/43 [==============================] - 7s 162ms/step - loss: 0.1547 - accuracy: 0.9394 - val_loss: 0.1211 - val_accuracy: 0.9533
# Epoch 29/50
# 43/43 [==============================] - 7s 154ms/step - loss: 0.1495 - accuracy: 0.9505 - val_loss: 0.1288 - val_accuracy: 0.9619
# Epoch 30/50
# 43/43 [==============================] - 7s 152ms/step - loss: 0.1675 - accuracy: 0.9264 - val_loss: 0.1268 - val_accuracy: 0.9498
# Epoch 31/50
# 43/43 [==============================] - 6s 147ms/step - loss: 0.1113 - accuracy: 0.9597 - val_loss: 0.1022 - val_accuracy: 0.9637
# Epoch 32/50
# 43/43 [==============================] - 7s 153ms/step - loss: 0.1025 - accuracy: 0.9589 - val_loss: 0.0963 - val_accuracy: 0.9585
# Epoch 33/50
# 43/43 [==============================] - 7s 161ms/step - loss: 0.1143 - accuracy: 0.9463 - val_loss: 0.1056 - val_accuracy: 0.9602
# Epoch 34/50
# 43/43 [==============================] - 7s 154ms/step - loss: 0.1409 - accuracy: 0.9464 - val_loss: 0.1074 - val_accuracy: 0.9637
# Epoch 35/50
# 43/43 [==============================] - 7s 152ms/step - loss: 0.1056 - accuracy: 0.9574 - val_loss: 0.0881 - val_accuracy: 0.9723
# Epoch 36/50
# 43/43 [==============================] - 6s 146ms/step - loss: 0.1036 - accuracy: 0.9556 - val_loss: 0.1108 - val_accuracy: 0.9567
# Epoch 37/50
# 43/43 [==============================] - 7s 157ms/step - loss: 0.1222 - accuracy: 0.9588 - val_loss: 0.0977 - val_accuracy: 0.9654
# Epoch 38/50
# 43/43 [==============================] - 7s 160ms/step - loss: 0.1105 - accuracy: 0.9434 - val_loss: 0.1251 - val_accuracy: 0.9567
# Epoch 39/50
# 43/43 [==============================] - 7s 153ms/step - loss: 0.1053 - accuracy: 0.9549 - val_loss: 0.1013 - val_accuracy: 0.9550
# Epoch 40/50
# 43/43 [==============================] - 7s 155ms/step - loss: 0.0995 - accuracy: 0.9640 - val_loss: 0.0940 - val_accuracy: 0.9602
# Epoch 41/50
# 43/43 [==============================] - 6s 148ms/step - loss: 0.0990 - accuracy: 0.9599 - val_loss: 0.0826 - val_accuracy: 0.9671
# Epoch 42/50
# 43/43 [==============================] - 7s 154ms/step - loss: 0.1115 - accuracy: 0.9595 - val_loss: 0.0780 - val_accuracy: 0.9706
# Epoch 43/50
# 43/43 [==============================] - 7s 164ms/step - loss: 0.0982 - accuracy: 0.9525 - val_loss: 0.1269 - val_accuracy: 0.9619
# Epoch 44/50
# 43/43 [==============================] - 6s 147ms/step - loss: 0.0988 - accuracy: 0.9524 - val_loss: 0.0718 - val_accuracy: 0.9706
# Epoch 45/50
# 43/43 [==============================] - 7s 154ms/step - loss: 0.1002 - accuracy: 0.9669 - val_loss: 0.0721 - val_accuracy: 0.9706
# Epoch 46/50
# 43/43 [==============================] - 6s 146ms/step - loss: 0.0905 - accuracy: 0.9697 - val_loss: 0.0716 - val_accuracy: 0.9810
# Epoch 47/50
# 43/43 [==============================] - 7s 155ms/step - loss: 0.1182 - accuracy: 0.9596 - val_loss: 0.0864 - val_accuracy: 0.9637
# Epoch 48/50
# 43/43 [==============================] - 7s 162ms/step - loss: 0.0949 - accuracy: 0.9655 - val_loss: 0.0813 - val_accuracy: 0.9723
# Epoch 49/50
# 43/43 [==============================] - 6s 147ms/step - loss: 0.0912 - accuracy: 0.9597 - val_loss: 0.0764 - val_accuracy: 0.9740
# Epoch 50/50
# 43/43 [==============================] - 7s 151ms/step - loss: 0.0851 - accuracy: 0.9629 - val_loss: 0.0702 - val_accuracy: 0.9671

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, "b", label="trainning accuracy")
plt.plot(epochs, val_accuracy, "r", label="validation accuracy")
plt.legend()
plt.show()

plt.plot(epochs, loss, "b", label="trainning loss")
plt.plot(epochs, val_loss, "r", label="validation loss")
plt.legend()
plt.show()

# %%
model.save("drowiness_new6.h5")

# %%
model.save("drowiness_new6.model")

# %%
prediction = model.predict_classes(X_test)
prediction
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([3, 3, 2, 3, 1, 3, 3, 2, 1, 2, 3, 3, 3, 2, 2, 2, 3, 0, 0, 2, 3, 3,
#        2, 1, 0, 2, 2, 2, 3, 2, 3, 2, 3, 2, 0, 3, 3, 2, 1, 2, 3, 3, 2, 3,
#        2, 2, 2, 3, 2, 3, 3, 1, 2, 1, 2, 3, 2, 2, 2, 0, 3, 3, 1, 2, 2, 3,
#        2, 3, 2, 2, 1, 3, 3, 3, 2, 0, 0, 3, 1, 3, 2, 0, 3, 2, 2, 2, 2, 1,
#        3, 3, 2, 3, 3, 3, 1, 0, 3, 0, 3, 3, 3, 1, 3, 1, 2, 3, 2, 1, 2, 2,
#        1, 1, 2, 1, 0, 3, 3, 3, 2, 2, 3, 3, 3, 1, 1, 2, 3, 2, 2, 0, 3, 3,
#        1, 3, 1, 2, 2, 3, 2, 1, 2, 2, 2, 1, 3, 3, 3, 3, 2, 0, 3, 3, 3, 3,
#        2, 0, 1, 0, 3, 1, 3, 2, 2, 3, 2, 3, 3, 2, 3, 2, 3, 1, 2, 0, 3, 3,
#        2, 2, 0, 2, 3, 1, 2, 0, 3, 3, 3, 1, 2, 0, 1, 3, 2, 2, 3, 2, 3, 0,
#        3, 2, 3, 0, 2, 0, 0, 1, 2, 3, 2, 0, 3, 1, 2, 2, 2, 2, 1, 3, 1, 1,
#        1, 0, 2, 3, 3, 3, 3, 0, 1, 2, 0, 1, 3, 3, 1, 3, 3, 0, 3, 3, 1, 0,
#        2, 0, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 2, 0, 2, 2, 2, 0, 3, 3, 2, 2,
#        3, 2, 2, 1, 2, 3, 2, 2, 2, 3, 3, 3, 3, 3, 0, 1, 0, 3, 3, 3, 3, 2,
#        2, 0, 2, 2, 2, 3, 2, 0, 2, 2, 1, 3, 2, 3, 1, 3, 3, 1, 3, 3, 0, 3,
#        3, 2, 2, 2, 1, 1, 0, 3, 3, 3, 3, 1, 2, 0, 3, 2, 2, 1, 3, 3, 3, 2,
#        2, 3, 2, 2, 3, 3, 3, 2, 1, 3, 2, 2, 2, 1, 2, 0, 3, 3, 2, 3, 2, 2,
#        2, 2, 3, 2, 0, 2, 1, 0, 2, 2, 2, 1, 3, 2, 3, 3, 3, 2, 2, 2, 2, 2,
#        2, 3, 1, 3, 3, 2, 3, 1, 3, 2, 2, 1, 0, 2, 2, 3, 2, 1, 3, 2, 2, 3,
#        2, 1, 0, 3, 0, 2, 3, 2, 2, 3, 1, 3, 3, 2, 3, 3, 1, 2, 3, 2, 2, 1,
#        1, 3, 2, 2, 3, 1, 3, 2, 2, 2, 2, 2, 0, 2, 0, 1, 2, 2, 1, 3, 2, 3,
#        3, 3, 2, 2, 3, 2, 1, 0, 2, 2, 2, 2, 2, 1, 2, 3, 3, 3, 1, 3, 2, 2,
#        2, 2, 3, 3, 0, 0, 2, 3, 3, 3, 2, 2, 2, 2, 2, 2, 2, 2, 1, 3, 3, 2,
#        2, 2, 2, 3, 2, 3, 3, 2, 3, 2, 3, 2, 3, 1, 0, 2, 2, 3, 2, 3, 0, 0,
#        1, 3, 2, 0, 3, 2, 2, 0, 2, 2, 3, 2, 3, 3, 3, 3, 2, 2, 0, 3, 2, 3,
#        2, 2, 3, 2, 2, 2, 3, 3, 2, 1, 2, 1, 3, 3, 1, 0, 3, 3, 3, 2, 2, 0,
#        2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 1, 3, 2, 2, 3, 3, 2, 3, 2, 3, 3, 2,
#        3, 2, 2, 3, 2, 2])

# %%
labels_new = ["yawn", "no_yawn", "Closed", "Open"]
from sklearn.metrics import classification_report
print(classification_report(np.argmax(y_test, axis=1), prediction, target_names=labels_new))
# Out:
#               precision    recall  f1-score   support
#
#         yawn       0.93      0.86      0.89        63
#      no_yawn       0.91      0.91      0.91        74
#       Closed       0.91      0.98      0.94       215
#         Open       0.98      0.93      0.95       226
#
#     accuracy                           0.94       578
#    macro avg       0.93      0.92      0.92       578
# weighted avg       0.94      0.94      0.94       578

# %%
labels_new = ["yawn", "no_yawn", "Closed", "Open"]
IMG_SIZE = 145
def prepare(filepath, face_cas="../input/predictionimages/haarcascade_frontalface_default.xml"):
    img_array = cv2.imread(filepath, cv2.IMREAD_COLOR)
    img_array = img_array / 255
    resized_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return resized_array.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

model = tf.keras.models.load_model("./drowiness_new6.h5")

# %%
prediction = model.predict([prepare("../input/drowsiness-dataset/train/no_yawn/1067.jpg")])
np.argmax(prediction)
# Out:
# 1

# %%
prediction = model.predict([prepare("../input/drowsiness-dataset/train/Closed/_101.jpg")])
np.argmax(prediction)
# Out:
# 2

# %%
prediction = model.predict([prepare("../input/drowsiness-dataset/train/Open/_104.jpg")])
np.argmax(prediction)
# Out:
# 3

# %%
prediction = model.predict([prepare("../input/drowsiness-dataset/train/yawn/113.jpg")])
np.argmax(prediction)
# Out:
# 3
